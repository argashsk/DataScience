# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import tensorflow as tf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df_train = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
df_test = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")

# %%
# ambil set kolom dari masing-masing dataframe
set1 = set(df_train.columns)
set2 = set(df_test.columns)

# ambil irisan dari kedua set kolom
intersection = set1.intersection(set2)

# buat dataframe baru hanya dengan kolom yang terdapat pada irisan
df1 = df_train[intersection]
df2 = df_test[intersection]

# %%
pd.options.display.max_rows = 10
df1.isna().sum()

# %%
df= df1.drop(["GarageType","BsmtExposure","LotFrontage","GarageYrBlt","GarageFinish","MasVnrArea","BsmtFinType1","GarageCond","Electrical","BsmtQual","BsmtCond","GarageQual","BsmtFinType2","LandSlope","Alley","FireplaceQu","PoolQC","Fence","MiscFeature","Street","CentralAir"],axis=1).copy()
dfd= df2.drop(["GarageType","BsmtExposure","LotFrontage","GarageYrBlt","GarageFinish","MasVnrArea","BsmtFinType1","GarageCond","Electrical","BsmtQual","BsmtCond","GarageQual","BsmtFinType2","LandSlope","Alley","FireplaceQu","PoolQC","Fence","MiscFeature","Street","CentralAir",],axis=1).copy()

# %%
df.dropna(inplace=True)
#dfd.dropna(inplace=True)

# %%
df['SalePrice'] = df_train['SalePrice']

# %%
dfd['SalePrice'] = df_train['SalePrice']

# %%
df.info()

# %%
dfd.info()

# %%
dfd.info()

# %%
dfd.Exterior1st.unique()

# %%
pd.options.display.max_rows = 100
dfd.isna().sum()

# %%
import statistics
from sklearn.impute import SimpleImputer

# %%
mean_imputer = SimpleImputer(missing_values = np.nan, strategy="mean")
median_imputer = SimpleImputer(missing_values = np.nan, strategy="median")
mf_imputer = SimpleImputer(missing_values = np.nan, strategy="most_frequent")

# %%
Exterior1st_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
Exterior1st_imp = Exterior1st_imp.fit(dfd[["Exterior1st"]])
dfd["Exterior1st"] = Exterior1st_imp.transform(dfd[["Exterior1st"]])

KitchenQual_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
KitchenQual_imp = KitchenQual_imp.fit(dfd[["KitchenQual"]])
dfd["KitchenQual"] = KitchenQual_imp.transform(dfd[["KitchenQual"]])

BsmtUnfSF_imp = SimpleImputer(strategy="median", missing_values = np.nan)
BsmtUnfSF_imp = BsmtUnfSF_imp.fit(dfd[["BsmtUnfSF"]])
dfd["BsmtUnfSF"] = BsmtUnfSF_imp.transform(dfd[["BsmtUnfSF"]])

BsmtFinSF2_imp = SimpleImputer(strategy="median", missing_values = np.nan)
BsmtFinSF2_imp = BsmtFinSF2_imp.fit(dfd[["BsmtFinSF2"]])
dfd["BsmtFinSF2"] = BsmtFinSF2_imp.transform(dfd[["BsmtFinSF2"]])

MasVnrType_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
MasVnrType_imp = MasVnrType_imp.fit(dfd[["MasVnrType"]])
dfd["MasVnrType"] = MasVnrType_imp.transform(dfd[["MasVnrType"]])

BsmtFinSF1_imp = SimpleImputer(strategy="median", missing_values = np.nan)
BsmtFinSF1_imp = BsmtFinSF1_imp.fit(dfd[["BsmtFinSF1"]])
dfd["BsmtFinSF1"] = BsmtFinSF1_imp.transform(dfd[["BsmtFinSF1"]])

Exterior2nd_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
Exterior2nd_imp = Exterior2nd_imp.fit(dfd[["Exterior2nd"]])
dfd["Exterior2nd"] = Exterior2nd_imp.transform(dfd[["Exterior2nd"]])

SaleType_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
SaleType_imp = SaleType_imp.fit(dfd[["SaleType"]])
dfd["SaleType"] = SaleType_imp.transform(dfd[["SaleType"]])

BsmtHalfBath_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
BsmtHalfBath_imp = BsmtHalfBath_imp.fit(dfd[["BsmtHalfBath"]])
dfd["BsmtHalfBath"] = BsmtHalfBath_imp.transform(dfd[["BsmtHalfBath"]])

GarageArea_imp = SimpleImputer(strategy="median", missing_values = np.nan)
GarageArea_imp = GarageArea_imp.fit(dfd[["GarageArea"]])
dfd["GarageArea"] = GarageArea_imp.transform(dfd[["GarageArea"]])

MSZoning_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
MSZoning_imp = MSZoning_imp.fit(dfd[["MSZoning"]])
dfd["MSZoning"] = MSZoning_imp.transform(dfd[["MSZoning"]])

TotalBsmtSF_imp = SimpleImputer(strategy="median", missing_values = np.nan)
TotalBsmtSF_imp = TotalBsmtSF_imp.fit(dfd[["TotalBsmtSF"]])
dfd["TotalBsmtSF"] = TotalBsmtSF_imp.transform(dfd[["TotalBsmtSF"]])

BsmtFullBath_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
BsmtFullBath_imp = BsmtFullBath_imp.fit(dfd[["BsmtFullBath"]])
dfd["BsmtFullBath"] = BsmtFullBath_imp.transform(dfd[["BsmtFullBath"]])

GarageCars_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
GarageCars_imp = GarageCars_imp.fit(dfd[["GarageCars"]])
dfd["GarageCars"] = GarageCars_imp.transform(dfd[["GarageCars"]])

Functional_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
Functional_imp = Functional_imp.fit(dfd[["Functional"]])
dfd["Functional"] = Functional_imp.transform(dfd[["Functional"]])

Utilities_imp = SimpleImputer(strategy="most_frequent", missing_values = np.nan)
Utilities_imp = Utilities_imp.fit(dfd[["Utilities"]])
dfd["Utilities"] = Utilities_imp.transform(dfd[["Utilities"]])

# %%
df_mod = pd.get_dummies(df)
dfd_mod = pd.get_dummies(dfd)

# %%
# ambil set kolom dari masing-masing dataframe
set3 = set(df_mod.columns)
set4 = set(dfd_mod.columns)

# ambil irisan dari kedua set kolom
intersection = set3.intersection(set4)

# buat dataframe baru hanya dengan kolom yang terdapat pada irisan
df11 = df_mod[intersection]
df22 = dfd_mod[intersection]

# %%
df11.info()

# %%
df22.info()

# %%
y_train = df11["SalePrice"].values
X_train = df11.drop(["SalePrice"],axis=1)
X_test = df22.drop(["SalePrice"],axis=1)

# %%
lr = RandomForestRegressor()
model_lr = lr.fit(X_train,y_train)
y_pred = model_lr.predict(X_test)

# %%
y_prediction = np.round(y_pred).flatten()

# %%
submission = pd.DataFrame({
    "Id":df22["Id"],
    "SalePrice":y_prediction    
})
submission

# %%
submission.to_csv("submission.csv",index=False)
